# %% [markdown]
# <a href="https://colab.research.google.com/github/theshashank1/cse-c5-3year-da/blob/main/cse_c5_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.Series([1, 2, 3], index=['a', 'b', 'c'])

# %%
df.loc[['a', 'c']]
# Out:
# a    1
# c    3
# dtype: int64

# %%
df = pd.Series({"names": "sreeja", 'age': 23})

# %%
df.loc['names']
# Out:
# 'sreeja'

# %%
df.iloc[0]
# Out:
# 'sreeja'

# %%
df = pd.DataFrame([['shashank', 25], ['sreeja', 26], ['sai', 550]], columns=['name', 'marks'], index = ['a', 'b', 'c'])
df
# Out:
#        name  marks
# a  shashank     25
# b    sreeja     26
# c       sai    550

# %%
df[['name', 'marks']].iloc[[0, 2]]
# Out:
#        name  marks
# a  shashank     25
# c       sai    550

# %%
df['name'].loc[['a', 'c']]
# Out:
# a    shashank
# c         sai
# Name: name, dtype: object

# %%
df = pd.DataFrame({
  'name': ['shashank', 'sreeja'],
  'marks':[25, 55]
})
df
# Out:
#        name  marks
# 0  shashank     25
# 1    sreeja     55

# %%
data = pd.read_csv('/content/zepto.csv')
data
# Out:
#     order_id       item       category price  quantity        city  \
# 0        101      Milk           Dairy    62         2   Hyderabad
# 1        102      Bread         Bakery    45         1   hyderabad
# 2        103      maggi  Packaged Food    20         3   Bengaluru
# 3        104  Eggs (12)          Dairy   ₹84         1     Chennai
# 4        105   Rice 5kg        Grocery   249         1   Hyderabad
# 5        106    Butter           Dairy    55         2   HYDERABAD
# 6        107     PANEER          dairy    90        -1     Chennai
# 7        108       Curd          Dairy    40         1   Bengaluru
# 8        109       Milk          Dairy   NaN         1         NaN
# 9        110     Bread          Bakery    45         0  hyderabad
# 10       111     Oil 1L        Grocery   150         1   Hyderabad
# 11       101      Milk           Dairy    62         2   Hyderabad
#
#     delivery_mins  order_date   plan
# 0              12  2025-01-15  Prime
# ...

# %%
data.columns
# Out:
# Index(['order_id', 'item', 'category', 'price', 'quantity', 'city',
#        'delivery_mins', 'order_date', 'plan'],
#       dtype='object')

# %%
data['price'] = data['price'].str.replace('₹', '')

# %%
data['price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 12 entries, 0 to 11
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 11 non-null     object
# dtypes: object(1)
# memory usage: 228.0+ bytes

# %%
data['price'] = data['price'].fillna(data['price'].mean())
data
# Out:
#     order_id       item       category  price  quantity        city  \
# 0        101      Milk           Dairy     62         2   Hyderabad
# 1        102      Bread         Bakery     45         1   hyderabad
# 2        103      maggi  Packaged Food     20         3   Bengaluru
# 3        104  Eggs (12)          Dairy     84         1     Chennai
# 4        105   Rice 5kg        Grocery    249         1   Hyderabad
# 5        106    Butter           Dairy     55         2   HYDERABAD
# 6        107     PANEER          dairy     90        -1     Chennai
# 7        108       Curd          Dairy     40         1   Bengaluru
# 8        109       Milk          Dairy      0         1         NaN
# 9        110     Bread          Bakery     45         0  hyderabad
# 10       111     Oil 1L        Grocery    150         1   Hyderabad
# 11       101      Milk           Dairy     62         2   Hyderabad
#
#     delivery_mins  order_date   plan
# 0              12  2025-01-15  Prime
# ...

# %%
data['price'] = data['price'].astype(int)

# %%
data[['order_id', 'item', 'price']][data['price'] < 20]
# Out:
#    order_id  item  price
# 8       109  Milk      0

# %%
data['price'].mean()
# Out:
# np.float64(75.16666666666667)

# %%
data.groupby('category', as_index=False)['price'].mean()
# Out:
#         category  price
# 0         Bakery   45.0
# 1          Dairy   50.5
# 2        Grocery  199.5
# 3  Packaged Food   20.0
# 4          dairy   90.0

# %%
data.isnull().sum()
# Out:
# order_id         0
# item             0
# category         0
# price            0
# quantity         0
# city             1
# delivery_mins    0
# order_date       0
# plan             3
# dtype: int64

# %%
data = data.dropna(subset='plan')

# %%
data.isnull().sum()
# Out:
# order_id         0
# item             0
# category         0
# price            0
# quantity         0
# city             1
# delivery_mins    0
# order_date       0
# plan             0
# dtype: int64

# %%
data = data.dropna(subset = 'city')

# %%
data
# Out:
#     order_id       item       category  price  quantity        city  \
# 0        101      Milk           Dairy     62         2   Hyderabad
# 2        103      maggi  Packaged Food     20         3   Bengaluru
# 3        104  Eggs (12)          Dairy     84         1     Chennai
# 4        105   Rice 5kg        Grocery    249         1   Hyderabad
# 6        107     PANEER          dairy     90        -1     Chennai
# 7        108       Curd          Dairy     40         1   Bengaluru
# 9        110     Bread          Bakery     45         0  hyderabad
# 11       101      Milk           Dairy     62         2   Hyderabad
#
#     delivery_mins  order_date   plan
# 0              12  2025-01-15  Prime
# 2              10  2025-01-16   Free
# 3             500  2025-01-16  Prime
# 4              18  16-01-2025   Free
# 6              11  2025-01-17  Prime
# 7               9  2025-01-18   Free
# 9              16  2025-01-19  Prime
# 11             12  2025-01-15  Prime

# %%
data.duplicated().sum()
# Out:
# np.int64(1)

# %%
data = data.drop_duplicates(keep='last')

# %%
data
# Out:
#     order_id       item       category  price  quantity        city  \
# 2        103      maggi  Packaged Food     20         3   Bengaluru
# 3        104  Eggs (12)          Dairy     84         1     Chennai
# 4        105   Rice 5kg        Grocery    249         1   Hyderabad
# 6        107     PANEER          dairy     90        -1     Chennai
# 7        108       Curd          Dairy     40         1   Bengaluru
# 9        110     Bread          Bakery     45         0  hyderabad
# 11       101      Milk           Dairy     62         2   Hyderabad
#
#     delivery_mins  order_date   plan
# 2              10  2025-01-16   Free
# 3             500  2025-01-16  Prime
# 4              18  16-01-2025   Free
# 6              11  2025-01-17  Prime
# 7               9  2025-01-18   Free
# 9              16  2025-01-19  Prime
# 11             12  2025-01-15  Prime

# %%
data.drop(columns='order_date')
# Out:
#     order_id       item       category  price  quantity        city  \
# 2        103      maggi  Packaged Food     20         3   Bengaluru
# 3        104  Eggs (12)          Dairy     84         1     Chennai
# 4        105   Rice 5kg        Grocery    249         1   Hyderabad
# 6        107     PANEER          dairy     90        -1     Chennai
# 7        108       Curd          Dairy     40         1   Bengaluru
# 9        110     Bread          Bakery     45         0  hyderabad
# 11       101      Milk           Dairy     62         2   Hyderabad
#
#     delivery_mins   plan
# 2              10   Free
# 3             500  Prime
# 4              18   Free
# 6              11  Prime
# 7               9   Free
# 9              16  Prime
# 11             12  Prime
