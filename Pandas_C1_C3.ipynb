# %% [markdown]
# <a href="https://colab.research.google.com/github/theshashank1/cse-c5-3year-da/blob/main/Pandas_C1_C3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
marks = pd.Series([99, 35, 40, 55], index = ['Sci', 'Soc', 'Math', 'Eng' ], name = 'marks', dtype = 'str')
marks
# Out:
# Sci     99
# Soc     35
# Math    40
# Eng     55
# Name: marks, dtype: object

# %%
marks['Sci']
# Out:
# '99'

# %%
marks.shape
# Out:
# (4,)

# %%
marks.dtype
# Out:
# dtype('O')

# %%
df = pd.DataFrame({'Name' : ['Shashank', 'Sreeja', 'Sai Teja'],
                       'Marks': [100, 120, 130]})
df
# Out:
#        Name  Marks
# 0  Shashank    100
# 1    Sreeja    120
# 2  Sai Teja    130

# %%
df = pd.DataFrame([['Shashank', 100], ['s', 120], ['d', 50] ], columns= ['Name', 'Marks'] )
df
# Out:
#        Name  Marks
# 0  Shashank    100
# 1         s    120
# 2         d     50

# %%
df = pd.read_csv('/content/zepto.csv')

# %%
df.head(10)
# Out:
#    order_id       item       category price  quantity        city  \
# 0       101      Milk           Dairy    62         2   Hyderabad
# 1       102      Bread         Bakery    45         1   hyderabad
# 2       103      maggi  Packaged Food    20         3   Bengaluru
# 3       104  Eggs (12)          Dairy   ₹84         1     Chennai
# 4       105   Rice 5kg        Grocery   249         1   Hyderabad
# 5       106    Butter           Dairy    55         2   HYDERABAD
# 6       107     PANEER          dairy    90        -1     Chennai
# 7       108       Curd          Dairy    40         1   Bengaluru
# 8       109       Milk          Dairy   NaN         1         NaN
# 9       110     Bread          Bakery    45         0  hyderabad
#
#    delivery_mins  order_date   plan
# 0             12  2025-01-15  Prime
# 1             15  15-01-2025    NaN
# 2             10  2025-01-16   Free
# 3            500  2025-01-16  Prime
# 4             18  16-01-2025   Free
# ...

# %%
df.tail()
# Out:
#     order_id    item category price  quantity        city  delivery_mins  \
# 7        108    Curd    Dairy    40         1   Bengaluru              9
# 8        109    Milk    Dairy   NaN         1         NaN             13
# 9        110  Bread    Bakery    45         0  hyderabad              16
# 10       111  Oil 1L  Grocery   150         1   Hyderabad             -5
# 11       101   Milk     Dairy    62         2   Hyderabad             12
#
#     order_date   plan
# 7   2025-01-18   Free
# 8   2025-01-18   Free
# 9   2025-01-19  Prime
# 10  2025-01-19    NaN
# 11  2025-01-15  Prime
